# %%
x=int(input())
j=x/100
k=x%100
l,m,p,r,s,pp=0,0,0,0,0,0
if k >49 :
    l=k/50
c=x-j*100-50*l

if c > 19:
    m=c/20
c=x-j*100-50*l-m*20
if c > 9:
    pp=c/10
c=x-j*100-50*l-m*20-pp*10
if c > 4:
    p=c/5
c=x-j*100-50*l-m*20-p*5-pp*10
if c>1:
    r=c/2
c=x-j*100-50*l-m*20-p*5-r*2-pp*10

see=j*100+l*50+m*20+p*5+r*2+c+pp*10
print "%d nota(s) de R$ 100,00"%j
print "%d nota(s) de R$ 50,00"%l
print "%d nota(s) de R$ 20,00"%m
print "%d nota(s) de R$ 10,00"%pp
print "%d nota(s) de R$ 5,00"%p
print "%d nota(s) de R$ 2,00"%r
print "%d nota(s) de R$ 1,00"%s

print "see ",see,"\n"
print j,"  ",l,"  ",m,"  ",pp,"  ",p," ",r,"  ",s

# %%
In this problem you have to read an integer value and calculate the smallest possible
number of banknotes in which the value may be decomposed. The possible banknotes are 
100, 50, 20, 10, 5, 2 e 1. Print the read value and the list of banknotes.

# %%
576
5 nota(s) de R$ 100,00
1 nota(s) de R$ 50,00
1 nota(s) de R$ 20,00
0 nota(s) de R$ 10,00
1 nota(s) de R$ 5,00
0 nota(s) de R$ 2,00
1 nota(s) de R$ 1,00

# %%
x=input()
j=x/100
k=x%100
l,m,p,r,s,pp=0,0,0,0,0,0
if k >49 :
    l=k/50
c=x-j*100-50*l

if c > 19:
    m=c/20
c=x-j*100-50*l-m*20
if c > 9:
    pp=c/10
c=x-j*100-50*l-m*20-pp*10
if c > 4:
    p=c/5
c=x-j*100-50*l-m*20-p*5-pp*10
if c>1:
    r=c/2
c=x-j*100-50*l-m*20-p*5-r*2-pp*10

print "NOTAS:"
print "%d nota(s) de R$ 100,00"%j
print "%d nota(s) de R$ 50,00"%l
print "%d nota(s) de R$ 20,00"%m
print "%d nota(s) de R$ 10,00"%pp
print "%d nota(s) de R$ 5,00"%p
print "%d nota(s) de R$ 2,00"%r
print "%d nota(s) de R$ 1,00"%s




#1, 0.50, 0.25, 0.10, 0.05 and 0.01

fx=c
print "f",c
y,s,q,t,f,nt=0,0,0,0,0,0
if c >.99:
    y=int(c)

c=fx-y
if c > .49:
    s=int(c/.5)
c=fx-y-.5*s
if c >.24:
    q=int(c/.25)
c=fx-y-.5*s-.25*q
if c > .09:
    t=int(c/.1)
c=fx-y-.5*s-.25*q-.1*t
if  c> .049:
    f=int(c/.05)
c=fx-y-.5*s-.25*q-.1*t-f*0.05
if c >0.009:
    nt=(c/.01)
    
    
print "MOEDAS:"
print "%d moeda(s) de R$ 1.00"%y
print "%d moeda(s) de R$ 0.50"%s
print "%d moeda(s) de R$ 0.25"%q
print "%d moeda(s) de R$ 0.10"%t
print "%d moeda(s) de R$ 0.05"%f
print "%d moeda(s) de R$ 0.01"%nt

# %%
11257

11257
112 nota(s) de R$ 100,00
1 nota(s) de R$ 50,00
0 nota(s) de R$ 20,00
0 nota(s) de R$ 10,00
1 nota(s) de R$ 5,00
1 nota(s) de R$ 2,00
0 nota(s) de R$ 1,00

503

503
5 nota(s) de R$ 100,00
0 nota(s) de R$ 50,00
0 nota(s) de R$ 20,00
0 nota(s) de R$ 10,00
0 nota(s) de R$ 5,00
1 nota(s) de R$ 2,00
1 nota(s) de R$ 1,00

# %%
c=7.0
if c == int(c):
    print "yaa"

# %%
c=1.99
fx=c
y,s,q,t,f,nt=0,0,0,0,0,0
if c > .99:
    y=int(c)

c=fx-y*1
if c > .49:
    s=int(c/.5)
    
print y,s

# %%
c=0.00
#1, 0.50, 0.25, 0.10, 0.05 and 0.01
print c
fx=c
y,s,q,t,f,nt=0,0,0,0,0,0
if c >.99:
    y=int(c)

c=fx-y
if c > .49:
    s=int(c/.5)
c=fx-y-.5*s
if c >.24:
    q=int(c/.25)
c=fx-y-.5*s-.25*q
if c > .09:
    t=int(c/.1)
c=fx-y-.5*s-.25*q-.1*t
if  c> .049:
    f=int(c/.05)
c=fx-y-.5*s-.25*q-.1*t-f*0.05
print c
if c >0.009:
    nt=(c/.01)
    print type(nt)
see= y+s*.5+.25*q+.1*t+.05*f+.01*nt
print "see %f"%see

# %%
x=float(input())
j=int(x/100)
k=x%100
l,m,p,r,s,pp=0,0,0,0,0,0
if k >49 :
    l=int(k/50)
c=x-j*100-50*l

if c > 19:
    m=int(c/20)
c=x-j*100-50*l-m*20
if c > 9:
    pp=int(c/10)
c=x-j*100-50*l-m*20-pp*10
if c > 4:
    p=int(c/5)
c=x-j*100-50*l-m*20-p*5-pp*10
if c>1:
    r=int(c/2)
c=x-j*100-50*l-m*20-p*5-r*2-pp*10
if c >0:
    s=c
print "%d"%x
print "%d nota(s) de R$ 100,00"%j
print "%d nota(s) de R$ 50,00"%l
print "%d nota(s) de R$ 20,00"%m
print "%d nota(s) de R$ 10,00"%pp
print "%d nota(s) de R$ 5,00"%p
print "%d nota(s) de R$ 2,00"%r
#print "%d nota(s) de R$ 1,00"%s



fx=s
print "f",fx
c=fx
y,s,q,t,f,nt=0,0,0,0,0,0
if c >.99:
    y=int(c)

c=fx-y
if c > .49:
    s=int(c/.5)
c=fx-y-.5*s
if c >.24:
    q=int(c/.25)
c=fx-y-.5*s-.25*q
if c > .09:
    t=int(c/.1)
c=fx-y-.5*s-.25*q-.1*t
if  c> .049:
    f=int(c/.05)
c=fx-y-.5*s-.25*q-.1*t-f*0.05
if c >0.009:
    nt=(c/.01)
    
    
print "MOEDAS:"
print "%d moeda(s) de R$ 1.00"%y
print "%d moeda(s) de R$ 0.50"%s
print "%d moeda(s) de R$ 0.25"%q
print "%d moeda(s) de R$ 0.10"%t
print "%d moeda(s) de R$ 0.05"%f
print "%d moeda(s) de R$ 0.01"%nt

# %%
x=float(input())
j=int(x/100)
k=x%100
l,m,p,r,s,pp=0,0,0,0,0,0
if k >49 :
    l=int(k/50)
c=x-j*100-50*l

if c > 19:
    m=int(c/20)
c=x-j*100-50*l-m*20
if c > 9:
    pp=int(c/10)
c=x-j*100-50*l-m*20-pp*10
if c > 4:
    p=int(c/5)
c=x-j*100-50*l-m*20-p*5-pp*10
if c>1:
    r=int(c/2)
c=x-j*100-50*l-m*20-p*5-r*2-pp*10
if c >0:
    s=c
print "NOTAS:"
print "%d nota(s) de R$ 100,00"%j
print "%d nota(s) de R$ 50,00"%l
print "%d nota(s) de R$ 20,00"%m
print "%d nota(s) de R$ 10,00"%pp
print "%d nota(s) de R$ 5,00"%p
print "%d nota(s) de R$ 2,00"%r
#print "%d nota(s) de R$ 1,00"%s



fx=s
c=fx
y,s,q,t,f,nt=0,0,0,0,0,0
if c >.99:
    y=int(c)

c=fx-y
if c > .49:
    s=int(c/.5)
c=fx-y-.5*s
if c >.24:
    q=int(c/.25)
c=fx-y-.5*s-.25*q
if c > .09:
    t=int(c/.1)
c=fx-y-.5*s-.25*q-.1*t
if  c> .049:
    f=int(c/.05)
c=fx-y-.5*s-.25*q-.1*t-f*0.05
if c >0.009:
    nt=(c/.01)
    
    
print "MOEDAS:"
print "%d moeda(s) de R$ 1.00"%y
print "%d moeda(s) de R$ 0.50"%s
print "%d moeda(s) de R$ 0.25"%q
print "%d moeda(s) de R$ 0.10"%t
print "%d moeda(s) de R$ 0.05"%f
print "%d moeda(s) de R$ 0.01"%nt
# Out:
# 576.03
# NOTAS:
# 5 nota(s) de R$ 100,00
# 1 nota(s) de R$ 50,00
# 1 nota(s) de R$ 20,00
# 0 nota(s) de R$ 10,00
# 1 nota(s) de R$ 5,00
# 0 nota(s) de R$ 2,00
# MOEDAS:
# 1 moeda(s) de R$ 1.00
# 0 moeda(s) de R$ 0.50
# 0 moeda(s) de R$ 0.25
# 0 moeda(s) de R$ 0.10
# 0 moeda(s) de R$ 0.05
# 2 moeda(s) de R$ 0.01

# %%
x=float((input()))
j=int(x/100)
k=x%100
l,m,p,r,s,pp=0,0,0,0,0,0
if k >49 :
    l=int(k/50)
c=x-j*100-50*l

if c > 19:
    m=int(c/20)
c=x-j*100-50*l-m*20
if c > 9:
    pp=int(c/10)
c=x-j*100-50*l-m*20-pp*10
if c > 4:
    p=int(c/5)
c=x-j*100-50*l-m*20-p*5-pp*10
if c>1:
    r=int(c/2)
c=x-j*100-50*l-m*20-p*5-r*2-pp*10
if c >0:
    s=c

#print "%d nota(s) de R$ 1,00"%s
print "NOTAS:"
print "%d nota(s) de R$ 100.00"%j
print "%d nota(s) de R$ 50.00"%l
print "%d nota(s) de R$ 20.00"%m
print "%d nota(s) de R$ 10.00"%pp
print "%d nota(s) de R$ 5.00"%p
print "%d nota(s) de R$ 2.00"%r 


fx=s
c=fx
y,s,q,t,f,nt=0,0,0,0,0,0
if c >.99:
    y=int(c)

c=fx-y
if c > .49:
    s=int(c/.5)
c=fx-y-.5*s
if c >.24:
    q=int(c/.25)
c=fx-y-.5*s-.25*q
if c > .09:
    t=int(c/.1)
c=fx-y-.5*s-.25*q-.1*t
if  c> .049:
    f=int(c/.05)
c=fx-y-.5*s-.25*q-.1*t-f*0.05
if c >0.009:
    nt=(c/.01)
    

print "MOEDAS:"
print "%d moeda(s) de R$ 1.00"%y
print "%d moeda(s) de R$ 0.50"%s
print "%d moeda(s) de R$ 0.25"%q
print "%d moeda(s) de R$ 0.10"%t
print "%d moeda(s) de R$ 0.05"%f
print "%d moeda(s) de R$ 0.01"%nt
# Out:
# 91.01
# NOTAS:
# 0 nota(s) de R$ 100.00
# 1 nota(s) de R$ 50.00
# 2 nota(s) de R$ 20.00
# 0 nota(s) de R$ 10.00
# 0 nota(s) de R$ 5.00
# 0 nota(s) de R$ 2.00
# MOEDAS:
# 1 moeda(s) de R$ 1.00
# 0 moeda(s) de R$ 0.50
# 0 moeda(s) de R$ 0.25
# 0 moeda(s) de R$ 0.10
# 0 moeda(s) de R$ 0.05
# 1 moeda(s) de R$ 0.01

# %%
91.01

NOTAS:
0 nota(s) de R$ 100.00
1 nota(s) de R$ 50.00
2 nota(s) de R$ 20.00
0 nota(s) de R$ 10.00
0 nota(s) de R$ 5.00
0 nota(s) de R$ 2.00
MOEDAS:
1 moeda(s) de R$ 1.00
0 moeda(s) de R$ 0.50
0 moeda(s) de R$ 0.25
0 moeda(s) de R$ 0.10
0 moeda(s) de R$ 0.05
1 moeda(s) de R$ 0.01












Input Sample	Output Sample
576.73

NOTAS:
5 nota(s) de R$ 100.00
1 nota(s) de R$ 50.00
1 nota(s) de R$ 20.00
0 nota(s) de R$ 10.00
1 nota(s) de R$ 5.00
0 nota(s) de R$ 2.00
MOEDAS:
1 moeda(s) de R$ 1.00
1 moeda(s) de R$ 0.50
0 moeda(s) de R$ 0.25
2 moeda(s) de R$ 0.10
0 moeda(s) de R$ 0.05
3 moeda(s) de R$ 0.01

4.00

# %%
NOTAS:
0 nota(s) de R$ 100.00
0 nota(s) de R$ 50.00
0 nota(s) de R$ 20.00
0 nota(s) de R$ 10.00
0 nota(s) de R$ 5.00
2 nota(s) de R$ 2.00
MOEDAS:
0 moeda(s) de R$ 1.00
0 moeda(s) de R$ 0.50
0 moeda(s) de R$ 0.25
0 moeda(s) de R$ 0.10
0 moeda(s) de R$ 0.05
0 moeda(s) de R$ 0.01

91.01

NOTAS:
0 nota(s) de R$ 100.00
1 nota(s) de R$ 50.00
2 nota(s) de R$ 20.00
0 nota(s) de R$ 10.00
0 nota(s) de R$ 5.00
0 nota(s) de R$ 2.00
MOEDAS:
1 moeda(s) de R$ 1.00
0 moeda(s) de R$ 0.50
0 moeda(s) de R$ 0.25
0 moeda(s) de R$ 0.10
0 moeda(s) de R$ 0.05
1 moeda(s) de R$ 0.01

# %%
value = eval(input());

cem = cinquenta = vinte = dez = cinco = dois = um = 0;
cincents = vintecincents = dezcents = cincocents = cents = 0;

value = float("%.2f" % value)
if int(value/100) >= 1:
 cem = int(value/100);
 value -= cem*100;

value = float("%.2f" % value)
if int(value/50) >= 1:
 cinquenta = int(value/50);
 value -= cinquenta*50;

value = float("%.2f" % value)
if int(value/20) >= 1:
 vinte = int(value/20.00);
 value -= vinte*20;

value = float("%.2f" % value)
if int(value/10) >= 1:
 dez = int(value/10);
 value -= dez*10.00;

value = float("%.2f" % value)
if int(value/5) >= 1:
 cinco = int(value/5);
 value -= cinco*5;

value = float("%.2f" % value)
if int(value/2) >= 1:
 dois = int(value/2);
 value -= dois*2;

value = float("%.2f" % value)
if int(value/1) >= 1:
 um = int(value/1);
 value -= um*1;

value = float("%.2f" % value)
if int(value/0.50) >= 1:
 cincents = int(value/0.50);
 value -= cincents*0.50;

value = float("%.2f" % value)
if int(value/0.25) >= 1:
 vintecincents = int(value/0.25);
 value -= vintecincents*0.25;

value = float("%.2f" % value)
if int(value/0.10) >= 1:
 dezcents = int(value/0.10);
 value -= dezcents*0.10;

value = float("%.2f" % value)
if int(value/0.05) >= 1:
 cincocents = int(value/0.05);
 value -= cincocents*0.05;

value = float("%.2f" % value)
if int(value/0.01) >= 0.998:
 cents = int(value/0.01);
 value -= cents*0.01;

print("NOTAS:");
print("%d nota(s) de R$ 100.00" % cem);
print("%d nota(s) de R$ 50.00" % cinquenta);
print("%d nota(s) de R$ 20.00" % vinte);
print("%d nota(s) de R$ 10.00" % dez);
print("%d nota(s) de R$ 5.00" % cinco);
print("%d nota(s) de R$ 2.00" % dois);

print("MOEDAS:");
print("%d moeda(s) de R$ 1.00" % um);
print("%d moeda(s) de R$ 0.50" % cincents);
print("%d moeda(s) de R$ 0.25" % vintecincents);
print("%d moeda(s) de R$ 0.10" % dezcents);
print("%d moeda(s) de R$ 0.05" % cincocents);
print("%d moeda(s) de R$ 0.01" % cents);
