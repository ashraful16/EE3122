# %%
inp=int(input())
i=0
nn=0
while i<1000:
    print "N[%d] = %d"%(i,nn)
    nn,i=nn+1,i+1
    if nn>=inp:
        nn=0
# Out:
# 4
# N[0] = 0
# N[1] = 1
# N[2] = 2
# N[3] = 3
# N[4] = 0
# N[5] = 1
# N[6] = 2
# N[7] = 3
# N[8] = 0
# N[9] = 1

# %%
inp=float(input())
i=0
nn=inp
while i<100:
    print "N[%d] = %.4f"%(i,nn)
    nn,i=nn/2,i+1
    if nn==inp:
        nn=0
# Out:
# 12
# N[0] = 12.0000
# N[1] = 6.0000
# N[2] = 3.0000
# N[3] = 1.5000
# N[4] = 0.7500
# N[5] = 0.3750
# N[6] = 0.1875
# N[7] = 0.0938
# N[8] = 0.0469
# N[9] = 0.0234
# N[10] = 0.0117
# N[11] = 0.0059
# N[12] = 0.0029
# N[13] = 0.0015
# N[14] = 0.0007
# N[15] = 0.0004
# N[16] = 0.0002
# N[17] = 0.0001
# N[18] = 0.0000
# N[19] = 0.0000
# N[20] = 0.0000
# N[21] = 0.0000
# N[22] = 0.0000
# N[23] = 0.0000
# N[24] = 0.0000
# N[25] = 0.0000
# N[26] = 0.0000
# N[27] = 0.0000
# N[28] = 0.0000
# N[29] = 0.0000
# N[30] = 0.0000
# N[31] = 0.0000
# N[32] = 0.0000
# N[33] = 0.0000
# N[34] = 0.0000
# N[35] = 0.0000
# N[36] = 0.0000
# N[37] = 0.0000
# N[38] = 0.0000
# N[39] = 0.0000
# N[40] = 0.0000
# N[41] = 0.0000
# N[42] = 0.0000
# N[43] = 0.0000
# N[44] = 0.0000
# N[45] = 0.0000
# N[46] = 0.0000
# N[47] = 0.0000
# N[48] = 0.0000
# N[49] = 0.0000
# N[50] = 0.0000
# N[51] = 0.0000
# N[52] = 0.0000
# N[53] = 0.0000
# N[54] = 0.0000
# N[55] = 0.0000
# N[56] = 0.0000
# N[57] = 0.0000
# N[58] = 0.0000
# ...
