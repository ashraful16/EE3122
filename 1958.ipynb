# %%
a=float(input())

if a>0:
    s='+'
else:
    s="-"

    
i=0
fl=True
while fl==True and s=="+" :
    c=a/(10**i)
    
    if c<1:
        fl=False
        kk=a/(10**(i-1))
        ss1='+'
        i=i-1
        #print(kk)
        break
    i+=1
       
while fl==True and s=="-":
    aa=-a
    c=aa/(10**i)
    
    if c<1:
        fl=False
        ss1='+'
        kk=a/(10**(i-1))
        i=i-1
        #print(kk)
        break

    i+=1

s1=False
if abs(a)>0 and abs(a)<1:
    s1=True
    i=1
    if a<0:
        
        aa=-a
    else:
        aa=a
    
while s1==True:
    c=aa*10**i
    
    if c>=1:
        s1=False
        kk=a*(10**(i))
        ss1='-'
        #print(kk)
        break
        
    i+=1
#print()


#print(kk,i)
print("tr \n")

if len(str(i))==1:
    i=str(0)+str(i)

print(str(s)+"%.4f"%abs(kk)+str('E')+str(ss1)+str(i))

# %%
a=float(input())

if a>0:
    s='+'
elif a<0:
    s="-"

    
i=0
fl=True
while fl==True and s=="+" :
    c=a/(10**i)
    
    if c<1:
        fl=False
        kk=a/(10**(i-1))
        ss1='+'
        i=i-1
        #print(kk)
        break
    i+=1
       
while fl==True and s=="-":
    aa=-a
    c=aa/(10**i)
    
    if c<1:
        fl=False
        ss1='+'
        kk=a/(10**(i-1))
        i=i-1
        #print(kk)
        break

    i+=1

s1=False
if abs(a)>0 and abs(a)<1:
    s1=True
    i=1
    if a<0:
        
        aa=-a
    else:
        aa=a
    
while s1==True:
    c=aa*10**i
    
    if c>=1:
        s1=False
        kk=a*(10**(i))
        ss1='-'
        #print(kk)
        break
        
    i+=1

if a==0:
    s='+'
    ss1='+'
    mu=str(a)
    if mu[0]=='-':
        s='-'
    i=0    
    
if len(str(i))==1:
    i=str(0)+str(i)

    

print(str(s)+"%.4f"%abs(kk)+str('E')+str(ss1)+str(i))
# Out:
# 12445
# +1.2445E+04

# %%
10
-1
12445

+1.0000E+01
-1.0000E+00
+1.2445E+04

# %%
a=float(input())

if a>0:
    s='+'
    
elif a<0:
    s="-"

if abs(a)>0:
    fl=True
i=0

while fl==True and s=="+" :
    c=a/(10**i)
    
    if c<1:
        fl=False
        kk=a/(10**(i-1))
        ss1='+'
        i=i-1
        #print(kk)
        break
    i+=1
       
while fl==True and s=="-":
    aa=-a
    c=aa/(10**i)
    
    if c<1:
        fl=False
        ss1='+'
        kk=a/(10**(i-1))
        i=i-1
        #print(kk)
        break

    i+=1

s1=False
if abs(a)>0 and abs(a)<1:
    s1=True
    i=1
    if a<0:
        
        aa=-a
    else:
        aa=a
    
while s1==True:
    c=aa*10**i
    
    if c>=1:
        s1=False
        kk=a*(10**(i))
        ss1='-'
        #print(kk)
        break
        
    i+=1

if a==0:
    s='+'
    ss1='+'
    mu=str(a)
    if mu[0]=='-':
        s='-'
    i=0    
    
if len(str(i))==1:
    i=str(0)+str(i)

    

print(str(s)+"%.4f"%abs(kk)+str('E')+str(ss1)+str(i))

# %%
cc=float(input())
c=("%.4E" %(cc))

if cc>0:
    s='+'
else:
    s='-'
    
c=str(s)+str(c)
print(c)
# Out:
# 53
# +5.3000E+01
